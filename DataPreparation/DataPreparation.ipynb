# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/intent2.0.csv', sep=';')
df[:3]
# Out:
#                                              content         intent
# 0                                        Спасибо нет  Благодарность
# 1  спасибо за ответ. мне этого достаточно пока чт...  Благодарность
# 2                                       спасибо, нет  Благодарность

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(df, test_size=0.33, random_state=42)

train.to_csv('/content/drive/MyDrive/ColabNotebooks/SkillBox/Data/train.csv', index=False)
test.to_csv('/content/drive/MyDrive/ColabNotebooks/SkillBox/Data/test.csv', index=False)
test.to_csv('/content/drive/MyDrive/ColabNotebooks/SkillBox/Data/valid.csv', index=False)

# %%
pd.read_csv('/content/drive/MyDrive/ColabNotebooks/SkillBox/Data/train.csv', sep=',')
# Out:
#                                                  content             intent
# 0               курс спортивной журналистики бесплатный?    Вопрос по курсу
# 1      Здравствуйте , не могу дозвониться до номера, ...  Ответ на недозвон
# 2      Ок, тогда можете мне позвонить 14:00 по телефо...  Ответ на недозвон
# 3             Нет, спасибо ничего не надо всё в порядке.      Благодарность
# 4            У вас есть рассрочка в Казахстанском рынке?     Цена/Рассрочка
# ...                                                  ...                ...
# 15285  К сожалению я не смогу связаться с вами ближай...       Консультация
# 15286      Или возможно есть условия рассрочки без банка     Цена/Рассрочка
# 15287                               Какие курсы имеются?    Вопрос по курсу
# 15288                                         Спасибо ❤️      Благодарность
# 15289  Доброго дня,такой вопросик почему мне бот скин...       Консультация
#
# [15290 rows x 2 columns]

# %%
pd.read_csv('/content/drive/MyDrive/ColabNotebooks/train.csv', sep=',')
# Out:
#                                                  content             intent
# 0      Добрый день. У вас есть, рассрочка не от банка...          Рассрочка
# 1                             От вас возможно рассрочка?          Рассрочка
# 2      Меня заинтересовал курс "Frontend-разработчик ...    Вопрос по курсу
# 3                                 Как проходит обучение?    Формат обучения
# 4      Я хотел бы поинтересоваться, по окончании курс...         Сертификат
# ...                                                  ...                ...
# 18616                 Нет пока финансовой возможности...              Отказ
# 18617  Хочу записаться на курс и как оформить вариант...          Рассрочка
# 18618  Добрый день! Актуальны ли курсы по Fashion-диз...    Вопрос по курсу
# 18619                                         Спасибо ??      Благодарность
# 18620  Прошу прощения, я работал. Мы можем завтра соз...  Ответ на недозвон
#
# [18621 rows x 2 columns]

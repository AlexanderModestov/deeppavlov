# %%
! pip install deeppavlov
! pip install transformers

# %%
from deeppavlov import configs, train_model
from deeppavlov.core.commands.utils import parse_config
from sklearn.model_selection import train_test_split
import json
import pandas as pd

# %%
config = parse_config('insults_kaggle_bert')

# %%
config = parse_config(configs.classifiers.insults_kaggle_bert)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path to the folder where you want to save the config
save_path = "/content/drive/MyDrive/ColabNotebooks/SkillBox/Configs/config_intents.json"

# Save the dictionary as a JSON file
with open(save_path, 'w') as f:
    json.dump(config, f, indent=4)

# %%
model = train_model(config, download=True)

# %%
! python -m deeppavlov riseapi /content/drive/MyDrive/ColabNotebooks/SkillBox/Configs/config_intents.json

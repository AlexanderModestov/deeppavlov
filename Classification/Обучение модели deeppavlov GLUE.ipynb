# %%
! pip install deeppavlov
! pip install datasets
! pip install transformers

# %%
# https://github.com/deeppavlov/DeepPavlov/blob/1.3.0/deeppavlov/configs/russian_super_glue/russian_superglue_terra_rubert.json

# %%
from deeppavlov import configs, train_model, build_model
from deeppavlov.core.commands.utils import parse_config
from sklearn.model_selection import train_test_split
import json
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#config = parse_config(configs.russian_super_glue.russian_superglue_terra_rubert)

# Path to the folder where you want to save the config
#save_path = "/content/drive/MyDrive/ColabNotebooks/SkillBox/Configs/russian_superglue_terra_rubert.json"

# Save the dictionary as a JSON file
#with open(save_path, 'w') as f:
#    json.dump(config, f, indent=4)

# %%
# !python3 -m deeppavlov train russian_superglue_terra_rubert

# %%
model=build_model(configs.russian_super_glue.russian_superglue_terra_rubert)
model(['Добрый день. У вас есть, рассрочка не от банка? Пример заплатил, месяц отучился)))'])

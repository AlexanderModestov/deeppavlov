# %%
! pip install deeppavlov

# %%
from deeppavlov import configs, train_model, build_model
from deeppavlov.core.commands.utils import parse_config
from sklearn.model_selection import train_test_split
import json
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/MyDrive/ColabNotebooks/intents.csv', 'r', encoding='utf-8') as file:
    content = file.read()

# %%
# !python3 -m deeppavlov train /content/drive/MyDrive/ColabNotebooks/config_rubert.json -d

# %%
df = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/intents.csv', delimiter=';', encoding='')

# Split the data into training and testing sets
#train, test = train_test_split(df, test_size=0.2, random_state=42)

#train.to_csv('/content/drive/MyDrive/ColabNotebooks/train.csv', sep='\t', index=False)
#test.to_csv('/content/drive/MyDrive/ColabNotebooks/valid.csv', sep='\t', index=False)

# %%
df
# Out:
#                                                  content           intent
# 0                                            Спасибо нет    Благодарность
# 1      спасибо за ответ. мне этого достаточно пока чт...    Благодарность
# 2                                           спасибо, нет    Благодарность
# 3                                               Спасибо!    Благодарность
# 4                                              Благодарю    Благодарность
# ...                                                  ...              ...
# 23272  Здравствуйте, меня зовут Дарья. Я хочу начать ...  Вопрос по курсу
# 23273  Добрый день, меня зовут Сергей. Интересует спе...             Цена
# 23274  Привет, мне интересен курс Fullstack-разработч...             Цена
# 23275  Сколько будут стоить курсы Веб-аналитик и Марк...             Цена
# 23276  Добрый день, меня зовут Сергей. Интересует спе...  Вопрос по курсу
#
# [23277 rows x 2 columns]

# %%
model_config = parse_config('/content/drive/MyDrive/ColabNotebooks/config_rubert.json')

# %%
#model_config

# %%
model = train_model(model_config, download=True)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-5-bee8814f59af> in <cell line: 1>()
# ----> 1 model = train_model(model_config, download=True)
#
# /usr/local/lib/python3.10/dist-packages/deeppavlov/__init__.py in train_model(config, install, download, recursive)
#      29 def train_model(config: [str, Path, dict], install: bool = False,
#      30                 download: bool = False, recursive: bool = False) -> Chainer:
# ---> 31     train_evaluate_model_from_config(config, install=install, download=download, recursive=recursive)
#      32     return build_model(config, load_trained=True)
#      33
#
# /usr/local/lib/python3.10/dist-packages/deeppavlov/core/commands/train.py in train_evaluate_model_from_config(config, iterator, to_train, evaluation_targets, install, download, start_epoch_num, recursive)
#      92     if iterator is None:
#      93         try:
# ...

# %%
# !python -m deeppavlov train '/content/drive/MyDrive/ColabNotebooks/config.json'
# Out:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.10/dist-packages/deeppavlov/__main__.py", line 4, in <module>
#     main()
#   File "/usr/local/lib/python3.10/dist-packages/deeppavlov/deep.py", line 67, in main
#     train_evaluate_model_from_config(pipeline_config_path,
#   File "/usr/local/lib/python3.10/dist-packages/deeppavlov/core/commands/train.py", line 94, in train_evaluate_model_from_config
#     data = read_data_by_config(config)
#   File "/usr/local/lib/python3.10/dist-packages/deeppavlov/core/commands/train.py", line 58, in read_data_by_config
#     return reader.read(**reader_config)
#   File "/usr/local/lib/python3.10/dist-packages/deeppavlov/dataset_readers/basic_classification_reader.py", line 83, in read
# ...

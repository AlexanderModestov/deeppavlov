# %%
! pip install deeppavlov
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.3/487.3 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.4/222.4 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 53.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 64.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
# ...

# %%
from deeppavlov import configs, train_model, build_model
from deeppavlov.core.commands.utils import parse_config
from sklearn.model_selection import train_test_split
import json
import pandas as pd

# %%
#!python3 -c "import torch; print(torch.cuda.is_available())"

# %%
# !python3 -m deeppavlov install fasttext_logreg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 48.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 26.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 7.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 25.6 MB/s eta 0:00:00
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=e9d6eda5a14acf63ecf6c90c5e0b088ffa3ec8a03a93411d562fdbc1e1b4a607
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built docopt
# ...
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.6.1
#     Uninstalling spacy-3.6.1:
#       Successfully uninstalled spacy-3.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
#!python3 -m deeppavlov install /content/drive/MyDrive/ColabNotebooks/config_faq.json -d

# %%
model_config = parse_config('fasttext_logreg')

# %%
# Path to the folder where you want to save the config
#save_path = "/content/drive/MyDrive/ColabNotebooks/config_faq.json"

# Save the dictionary as a JSON file
#with open(save_path, 'w') as f:
#    json.dump(model_config, f, indent=4)

# %%
model_config

# %%
#config = json.load(open(configs.faq.fasttext_logreg))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/intents.csv', delimiter=';') #, encoding='cp1251')

# Split the data into training and testing sets
train, test = train_test_split(df, test_size=0.2, random_state=42)

train.to_csv('/content/drive/MyDrive/ColabNotebooks/train.csv')
test.to_csv('/content/drive/MyDrive/ColabNotebooks/test.csv')

# %%
model_config['dataset_reader']['x'] = 'content'
model_config['dataset_reader']['y'] = 'intent'
model_config['metadata']['variables']['LANGUAGE']='ru'
model_config['metadata']['variables']['SPACY_MODEL']='ru_core_web_sm'
model_config['metadata']['variables']['ROOT_PATH']='/content/drive/MyDrive/ColabNotebooks/FAQ'
model_config['metadata']['variables']['DOWNLOADS_PATH']='/content/drive/MyDrive/ColabNotebooks/FAQ/downloads'
model_config['metadata']['variables']['MODEL_PATH']='/content/drive/MyDrive/ColabNotebooks/FAQ/model'
model_config['chainer']['pipe'][2]['load_path']='/content/drive/MyDrive/ColabNotebooks/FAQ/downloads/embeddings/fasttext/ru.bin'
model_config['chainer']['pipe'][3]['save_path']='/content/drive/MyDrive/ColabNotebooks/FAQ/model/faq/ru/fasttext_logreg/cat_answers.dict'
model_config['chainer']['pipe'][3]['load_path']='/content/drive/MyDrive/ColabNotebooks/FAQ/model/faq/ru/fasttext_logreg/cat_answers.dict'
model_config['metadata']['download'][0]['url']='http://files.deeppavlov.ai/embeddings/fasttext/ru.bin'
model_config['metadata']['download'][0]['subdir']='/content/drive/MyDrive/ColabNotebooks/FAQ/downloads/embeddings/fasttext'
model_config['metadata']['download'][1]['url']='http://files.deeppavlov.ai/datasets/massive-ru.tar.gz'
model_config['metadata']['download'][1]['subdir']='/content/drive/MyDrive/ColabNotebooks/FAQ/downloads/massive/ru'
model_config['metadata']['download'][2]['url']='http://files.deeppavlov.ai/faq/fasttext_logreg_ru.tar.gz'
model_config['metadata']['download'][2]['subdir']='/content/drive/MyDrive/ColabNotebooks/FAQ/model/faq/ru/fasttext_logreg'
model_config['chainer']['pipe'][4]['save_path']='/content/drive/MyDrive/ColabNotebooks/FAQ/model/faq/ru/fasttext_logreg/model.pkl'
model_config['chainer']['pipe'][4]['load_path']='/content/drive/MyDrive/ColabNotebooks/FAQ/model/faq/ru/fasttext_logreg/model.pkl'
model_config['chainer']['pipe'][0]['spacy_model']='ru_core_news_sm'
model_config['dataset_reader']['data_path']='/content/drive/MyDrive/ColabNotebooks'
model_config['dataset_reader']['format']='csv'
model_config['dataset_reader']['train']='train.csv'
model_config['dataset_reader']['valid']='test.csv'
model_config['dataset_reader']['test']='test.csv'

# %%
model = train_model(model_config, download=True)
# Out:
# 2023-09-07 05:54:29.646 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/datasets/massive-ru.tar.gz download because of matching hashes
# INFO:deeppavlov.download:Skipped http://files.deeppavlov.ai/datasets/massive-ru.tar.gz download because of matching hashes
# 2023-09-07 05:54:30.376 INFO in 'deeppavlov.core.data.utils'['utils'] at line 95: Downloading from http://files.deeppavlov.ai/embeddings/fasttext/ru.bin to /content/drive/MyDrive/ColabNotebooks/FAQ/downloads/embeddings/fasttext/ru.bin
# INFO:deeppavlov.core.data.utils:Downloading from http://files.deeppavlov.ai/embeddings/fasttext/ru.bin to /content/drive/MyDrive/ColabNotebooks/FAQ/downloads/embeddings/fasttext/ru.bin
# 100%|██████████| 1.11G/1.11G [00:39<00:00, 28.4MB/s]
# 2023-09-07 05:55:13.625 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/faq/fasttext_logreg_ru.tar.gz download because of matching hashes
# ...

# %%
model
